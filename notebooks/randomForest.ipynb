# %%
import matplotlib.pyplot as plt

# %%
import sys
import os

# Go up one level from notebooks/ to project/, then into src/
module_path = os.path.abspath(os.path.join('..', 'src'))
if module_path not in sys.path:
    sys.path.append(module_path)
#from chatgpt - but can't figure out how to make it work

# %%
#from train_models here are my results for cross validation of randomForest
Scores = [0.99974551, 0.99970736, 0.99974111, 0.99970577, 0.99089616]
cv = [1, 2, 3, 4, 5]

# %%
plt.scatter(cv, Scores)
plt.xlabel("Cross-Validation")
plt.ylabel("Scores");
