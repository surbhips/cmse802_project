# %% [markdown]
# ## Results

# %% [markdown]
# ### From EDA

# %% [markdown]
# ![download.png](attachment:e8e8b32a-8d90-4b6a-94e1-248f40168e12.png)

# %% [markdown]
# ### PCA

# %% [markdown]
# ![download.png](attachment:06d99e1d-3dc6-40c0-a87c-a6855e7d4e1e.png)

# %% [markdown]
# ![download.png](attachment:6de55a0e-14dd-4ce7-a6de-08680eb2771b.png)

# %% [markdown]
# ### Models Actual vs Predicted Values

# %% [markdown]
# ### Random Forest

# %% [markdown]
# ![download.png](attachment:6bf5eeb5-217a-4a2c-a5e6-f8c0a4bc3f02.png) ![download.png](attachment:75418f87-b177-4957-a8f2-c5db99298cd3.png)

# %% [markdown]
# ### Linear Regression

# %% [markdown]
# ![download.png](attachment:0a216972-2a57-44e2-9d77-6a4a380ec4c6.png)

# %% [markdown]
# ### Decision Tree

# %% [markdown]
# ![download.png](attachment:5b6d9931-73c7-45e3-b67c-fa5bfe446f8a.png)![download.png](attachment:1256f809-14c2-4927-b1fe-62d05ee6c9b2.png)

# %% [markdown]
# ### SVR

# %% [markdown]
# ![download.png](attachment:52ddaa93-866c-427b-a9ca-214ce25a2458.png)

# %% [markdown]
# ### XGBoost

# %% [markdown]
# ![download.png](attachment:ece78576-a2dc-4589-a799-4c7d516d76ce.png)

# %% [markdown]
# ## Residuals

# %% [markdown]
# ![download.png](attachment:0b2fd023-e9a6-44ac-94fb-286c1d0eb9cd.png)
